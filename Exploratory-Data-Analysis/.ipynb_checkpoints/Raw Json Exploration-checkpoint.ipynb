# %%
import pandas as pd
import json

ticker_file = open('../Data/Raw Request Data/GOOGL_Annual_Financials.json')

ticker_json = json.load(open('../Data/Raw Request Data/GOOGL_Annual_Financials.json'))

pre_df = ticker_json['results'][0]

Google_DF = pd.DataFrame(ticker_json['results'])

# %%
CREATE TABLE comprehensive_income

# %%
Google_DF.head(3)
# Out:
#                    id  start_date    end_date filing_date timeframe  \
# 0  0001652044:2016:FY  2016-01-01  2016-12-31  2017-02-03    annual
# 1  0001652044:2017:FY  2017-01-01  2017-12-31  2018-02-06    annual
# 2  0001652044:2018:FY  2018-01-01  2018-12-31  2019-02-05    annual
#
#   fiscal_period fiscal_year         cik   sic        tickers   company_name  \
# 0            FY        2016  0001652044  7370  [GOOG, GOOGL]  Alphabet Inc.
# 1            FY        2017  0001652044  7370  [GOOG, GOOGL]  Alphabet Inc.
# 2            FY        2018  0001652044  7370  [GOOG, GOOGL]  Alphabet Inc.
#
#                                    source_filing_url  \
# 0  https://api.polygon.io/v1/reference/sec/filing...
# 1  https://api.polygon.io/v1/reference/sec/filing...
# 2  https://api.polygon.io/v1/reference/sec/filing...
#
#                               source_filing_file_url  \
# 0  http://api.polygon.io/v1/reference/sec/filings...
# 1  http://api.polygon.io/v1/reference/sec/filings...
# ...

# %%
Google_Stripped = Google_DF.drop(['source_filing_url', 'source_filing_file_url', 'cik', 'timeframe'], axis = 1)
Google_Stripped
# Out:
#                    id  start_date    end_date filing_date fiscal_period  \
# 0  0001652044:2016:FY  2016-01-01  2016-12-31  2017-02-03            FY
# 1  0001652044:2017:FY  2017-01-01  2017-12-31  2018-02-06            FY
# 2  0001652044:2018:FY  2018-01-01  2018-12-31  2019-02-05            FY
# 3  0001652044:2019:FY  2019-01-01  2019-12-31  2020-02-04            FY
# 4  0001652044:2020:FY  2020-01-01  2020-12-31  2021-02-03            FY
# 5  0001652044:2021:FY  2021-01-01  2021-12-31  2022-02-02            FY
#
#   fiscal_year   sic        tickers   company_name  \
# 0        2016  7370  [GOOG, GOOGL]  Alphabet Inc.
# 1        2017  7370  [GOOG, GOOGL]  Alphabet Inc.
# 2        2018  7370  [GOOG, GOOGL]  Alphabet Inc.
# 3        2019  7370  [GOOG, GOOGL]  Alphabet Inc.
# 4        2020  7370  [GOOG, GOOGL]  Alphabet Inc.
# 5        2021  7370  [GOOG, GOOGL]  Alphabet Inc.
#
#                                           financials
# ...

# %%
Google_Stripped['financials'][0]['comprehensive_income'].keys()
# Out:
# dict_keys(['other_comprehensive_income_loss_attributable_to_parent', 'comprehensive_income_loss_attributable_to_noncontrolling_interest', 'comprehensive_income_loss', 'other_comprehensive_income_loss', 'comprehensive_income_loss_attributable_to_parent'])

# %%
for key, value in Google_Stripped['financials'][0].items():
    print(f'-----------{key}-----------')
    for line in value:
        print(line)
# Out:
# -----------comprehensive_income-----------
# other_comprehensive_income_loss_attributable_to_parent
# comprehensive_income_loss_attributable_to_noncontrolling_interest
# comprehensive_income_loss
# other_comprehensive_income_loss
# comprehensive_income_loss_attributable_to_parent
# -----------income_statement-----------
# cost_of_revenue
# net_income_loss_attributable_to_parent
# gross_profit
# net_income_loss_available_to_common_stockholders_basic
# operating_income_loss
# income_tax_expense_benefit
# income_tax_expense_benefit_current
# income_tax_expense_benefit_deferred
# benefits_costs_expenses
# participating_securities_distributed_and_undistributed_earnings_loss_basic
# income_loss_from_equity_method_investments
# income_loss_before_equity_method_investments
# revenues
# net_income_loss_attributable_to_noncontrolling_interest
# operating_expenses
# preferred_stock_dividends_and_other_adjustments
# nonoperating_income_loss
# net_income_loss
# ...

# %%
ticker_json
# Out:
# {'results': [{'id': '0001652044:2016:FY',
#    'start_date': '2016-01-01',
#    'end_date': '2016-12-31',
#    'filing_date': '2017-02-03',
#    'timeframe': 'annual',
#    'fiscal_period': 'FY',
#    'fiscal_year': '2016',
#    'cik': '0001652044',
#    'sic': '7370',
#    'tickers': ['GOOG', 'GOOGL'],
#    'company_name': 'Alphabet Inc.',
#    'source_filing_url': 'https://api.polygon.io/v1/reference/sec/filings/0001652044-17-000008',
#    'source_filing_file_url': 'http://api.polygon.io/v1/reference/sec/filings/0001652044-17-000008/files/goog-20161231.xml',
#    'financials': {'comprehensive_income': {'other_comprehensive_income_loss_attributable_to_parent': {'value': -528000000.0,
#       'unit': 'USD',
#       'label': 'Other Comprehensive Income/Loss Attributable To Parent',
#       'order': 600},
#      'comprehensive_income_loss_attributable_to_noncontrolling_interest': {'value': 0,
#       'unit': 'USD',
# ...
